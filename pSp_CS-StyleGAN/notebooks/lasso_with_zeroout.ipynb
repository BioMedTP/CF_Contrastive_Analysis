# %%
# locate the root folder
CODE_DIR = '/home/ids/yuhe/Projects/CA_with_GAN/3_code_styleGAN/pSp_encoder_constructive/'

import os
os.chdir(f'{CODE_DIR}')

notebook_path = os.getcwd()
print('Current working directory is:', '\n', notebook_path) 

# import time
# import math
# from typing import Tuple, Optional, List

import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import torch.nn.functional as F
import matplotlib.pyplot as plt
from notebooks.def_lasso_functions import validate, train_model_function, get_model_weights_info, show_latent_map, Options, calculate_latent_loss, calculate_weight_sparsity, calculate_output_sparsity, plot_results, plot_comparison_curves
# Out:
# Current working directory is:
#  /home/ids/yuhe/Projects/CA_with_GAN/3_code_styleGAN/pSp_encoder_constructive

# %% [markdown]
# ### Test zero_out threshold effect

# %%
num_epochs = 1000
learning_rate=0.01

zero_out_bg=False
zero_out_t=True
zero_out_threshold=0.001
zero_out_type='hard'

lasso_weight_lambda=0.00

params_list=[0.0, 0.001, 0.01, 0.1]  # zero_out_threshold

weight_sparsity = {}
sbg_sparsity = {}
st_sparsity = {}
lasso_sbg_losses = {}
lasso_st_losses = {}
lasso_weight_losses = {}
MSE_losses = {}
trained_models = {}


for param in params_list:

    trained_model, trackers, latent_bg_target, latent_t_target = train_model_function(num_epochs=num_epochs, learning_rate=0.01, 
                                                    style_dim=18, latent_dim=512, mlp_norm_type='no_dim',
                                                    zero_out_bg=False, zero_out_t=False, zero_out_threshold=zero_out_threshold, zero_out_type=zero_out_type, 
                                                    lasso_sbg_lambda=param, lasso_st_lambda=param, lasso_output_type='element', 
                                                    lasso_weight_lambda=lasso_weight_lambda, lasso_weight_type='all', 
                                                    track_weight_threshold=0.0, track_output_threshold=0.0,
                                                    plot_curves=False, device='cuda')
    
    # Store the results and trained model for the current lasso_output_lambda
    weight_sparsity[param] = trackers['weight_sparsity_tracker']
    sbg_sparsity[param] = trackers['sbg_sparsity_tracker']
    st_sparsity[param] = trackers['st_sparsity_tracker']
    lasso_sbg_losses[param] = trackers['lasso_sbg_tracker']
    lasso_st_losses[param] = trackers['lasso_st_tracker']
    lasso_weight_losses[param] = trackers['lasso_weight_tracker']
    MSE_losses[param] = trackers['latent_MSE_tracker']
    trained_models[param] = trained_model

plot_comparison_curves(sbg_sparsity, title = 'Sbg sparsity', label_title='threshold')
plot_comparison_curves(st_sparsity,'St sparsity', label_title='threshold')
plot_comparison_curves(lasso_sbg_losses,'St sparsity', label_title='threshold')
plot_comparison_curves(lasso_st_losses,'St sparsity', label_title='threshold')

for param in params_list:
    latent_bg_s, latent_t_s = validate(trained_models[param], latent_bg_target, latent_t_target)
    show_latent_map(latent_t_s, img_idx = 0, show_weight = 50)
# Out:
# Using device: cuda
#
# Training with zero_out_threshold = 0.0, lasso_sbg_lambda = 0.0, lasso_st_lambda = 0.0, lasso_weight_lambda = 0.0
# Epoch [1/1000], MSE loss: 2.0230, Lasso sbg loss: 0.0000, Lasso st loss: 0.0000, Lasso weight loss: 0.0000, Weight Sparsity: 0.0000 (0 of 37748736), Sbg Sparsity: 0.0000 (0 of 36864), St Sparsity: 0.0000 (0 of 36864)
# Epoch [101/1000], MSE loss: 0.0002, Lasso sbg loss: 0.0000, Lasso st loss: 0.0000, Lasso weight loss: 0.0000, Weight Sparsity: 0.0000 (0 of 37748736), Sbg Sparsity: 0.0000 (0 of 36864), St Sparsity: 0.0000 (0 of 36864)
# Epoch [201/1000], MSE loss: 0.0001, Lasso sbg loss: 0.0000, Lasso st loss: 0.0000, Lasso weight loss: 0.0000, Weight Sparsity: 0.0000 (0 of 37748736), Sbg Sparsity: 0.0000 (0 of 36864), St Sparsity: 0.0000 (0 of 36864)
# Epoch [301/1000], MSE loss: 0.0001, Lasso sbg loss: 0.0000, Lasso st loss: 0.0000, Lasso weight loss: 0.0000, Weight Sparsity: 0.0000 (0 of 37748736), Sbg Sparsity: 0.0000 (0 of 36864), St Sparsity: 0.0000 (0 of 36864)
# Epoch [401/1000], MSE loss: 0.0002, Lasso sbg loss: 0.0000, Lasso st loss: 0.0000, Lasso weight loss: 0.0000, Weight Sparsity: 0.0000 (0 of 37748736), Sbg Sparsity: 0.0000 (0 of 36864), St Sparsity: 0.0000 (0 of 36864)
# Epoch [501/1000], MSE loss: 0.0003, Lasso sbg loss: 0.0000, Lasso st loss: 0.0000, Lasso weight loss: 0.0000, Weight Sparsity: 0.0000 (0 of 37748736), Sbg Sparsity: 0.0000 (0 of 36864), St Sparsity: 0.0000 (0 of 36864)
# Epoch [601/1000], MSE loss: 0.0002, Lasso sbg loss: 0.0000, Lasso st loss: 0.0000, Lasso weight loss: 0.0000, Weight Sparsity: 0.0000 (0 of 37748736), Sbg Sparsity: 0.0000 (0 of 36864), St Sparsity: 0.0000 (0 of 36864)
# Epoch [701/1000], MSE loss: 0.0002, Lasso sbg loss: 0.0000, Lasso st loss: 0.0000, Lasso weight loss: 0.0000, Weight Sparsity: 0.0000 (0 of 37748736), Sbg Sparsity: 0.0000 (0 of 36864), St Sparsity: 0.0000 (0 of 36864)
# Epoch [801/1000], MSE loss: 0.0003, Lasso sbg loss: 0.0000, Lasso st loss: 0.0000, Lasso weight loss: 0.0000, Weight Sparsity: 0.0000 (0 of 37748736), Sbg Sparsity: 0.0000 (0 of 36864), St Sparsity: 0.0000 (0 of 36864)
# Epoch [901/1000], MSE loss: 0.0006, Lasso sbg loss: 0.0000, Lasso st loss: 0.0000, Lasso weight loss: 0.0000, Weight Sparsity: 0.0000 (0 of 37748736), Sbg Sparsity: 0.0000 (0 of 36864), St Sparsity: 0.0000 (0 of 36864)
# Using device: cuda
#
# Training with zero_out_threshold = 0.001, lasso_sbg_lambda = 0.0, lasso_st_lambda = 0.0, lasso_weight_lambda = 0.0
# Epoch [1/1000], MSE loss: 2.0583, Lasso sbg loss: 0.0000, Lasso st loss: 0.0000, Lasso weight loss: 0.0000, Weight Sparsity: 0.0000 (0 of 37748736), Sbg Sparsity: 0.0242 (893 of 36864), St Sparsity: 0.0241 (887 of 36864)
# Epoch [101/1000], MSE loss: 0.0002, Lasso sbg loss: 0.0000, Lasso st loss: 0.0000, Lasso weight loss: 0.0000, Weight Sparsity: 0.0000 (0 of 37748736), Sbg Sparsity: 0.0391 (1442 of 36864), St Sparsity: 0.0015 (55 of 36864)
# Epoch [201/1000], MSE loss: 0.0001, Lasso sbg loss: 0.0000, Lasso st loss: 0.0000, Lasso weight loss: 0.0000, Weight Sparsity: 0.0000 (0 of 37748736), Sbg Sparsity: 0.1198 (4418 of 36864), St Sparsity: 0.0031 (114 of 36864)
# Epoch [301/1000], MSE loss: 0.0001, Lasso sbg loss: 0.0000, Lasso st loss: 0.0000, Lasso weight loss: 0.0000, Weight Sparsity: 0.0000 (0 of 37748736), Sbg Sparsity: 0.2087 (7693 of 36864), St Sparsity: 0.0039 (142 of 36864)
# Epoch [401/1000], MSE loss: 0.0002, Lasso sbg loss: 0.0000, Lasso st loss: 0.0000, Lasso weight loss: 0.0000, Weight Sparsity: 0.0000 (0 of 37748736), Sbg Sparsity: 0.2911 (10731 of 36864), St Sparsity: 0.0032 (117 of 36864)
# Epoch [501/1000], MSE loss: 0.0001, Lasso sbg loss: 0.0000, Lasso st loss: 0.0000, Lasso weight loss: 0.0000, Weight Sparsity: 0.0000 (0 of 37748736), Sbg Sparsity: 0.3934 (14503 of 36864), St Sparsity: 0.0027 (100 of 36864)
# Epoch [601/1000], MSE loss: 0.0002, Lasso sbg loss: 0.0000, Lasso st loss: 0.0000, Lasso weight loss: 0.0000, Weight Sparsity: 0.0000 (0 of 37748736), Sbg Sparsity: 0.4764 (17561 of 36864), St Sparsity: 0.0020 (73 of 36864)
# Epoch [701/1000], MSE loss: 0.0003, Lasso sbg loss: 0.0000, Lasso st loss: 0.0000, Lasso weight loss: 0.0000, Weight Sparsity: 0.0000 (0 of 37748736), Sbg Sparsity: 0.5187 (19123 of 36864), St Sparsity: 0.0018 (66 of 36864)
# Epoch [801/1000], MSE loss: 0.0004, Lasso sbg loss: 0.0000, Lasso st loss: 0.0000, Lasso weight loss: 0.0000, Weight Sparsity: 0.0000 (0 of 37748736), Sbg Sparsity: 0.6149 (22669 of 36864), St Sparsity: 0.0014 (50 of 36864)
# Epoch [901/1000], MSE loss: 0.0001, Lasso sbg loss: 0.0000, Lasso st loss: 0.0000, Lasso weight loss: 0.0000, Weight Sparsity: 0.0000 (0 of 37748736), Sbg Sparsity: 0.6819 (25136 of 36864), St Sparsity: 0.0012 (44 of 36864)
# Using device: cuda
#
# Training with zero_out_threshold = 0.01, lasso_sbg_lambda = 0.0, lasso_st_lambda = 0.0, lasso_weight_lambda = 0.0
# Epoch [1/1000], MSE loss: 2.0290, Lasso sbg loss: 0.0000, Lasso st loss: 0.0000, Lasso weight loss: 0.0000, Weight Sparsity: 0.0000 (0 of 37748736), Sbg Sparsity: 0.2366 (8721 of 36864), St Sparsity: 0.2347 (8651 of 36864)
# Epoch [101/1000], MSE loss: 0.0002, Lasso sbg loss: 0.0000, Lasso st loss: 0.0000, Lasso weight loss: 0.0000, Weight Sparsity: 0.0000 (0 of 37748736), Sbg Sparsity: 0.4104 (15128 of 36864), St Sparsity: 0.0235 (868 of 36864)
# Epoch [201/1000], MSE loss: 0.0000, Lasso sbg loss: 0.0000, Lasso st loss: 0.0000, Lasso weight loss: 0.0000, Weight Sparsity: 0.0000 (0 of 37748736), Sbg Sparsity: 0.8125 (29952 of 36864), St Sparsity: 0.0264 (972 of 36864)
# Epoch [301/1000], MSE loss: 0.0001, Lasso sbg loss: 0.0000, Lasso st loss: 0.0000, Lasso weight loss: 0.0000, Weight Sparsity: 0.0000 (0 of 37748736), Sbg Sparsity: 0.9529 (35127 of 36864), St Sparsity: 0.0273 (1005 of 36864)
# Epoch [401/1000], MSE loss: 0.0002, Lasso sbg loss: 0.0000, Lasso st loss: 0.0000, Lasso weight loss: 0.0000, Weight Sparsity: 0.0000 (0 of 37748736), Sbg Sparsity: 0.9969 (36749 of 36864), St Sparsity: 0.0281 (1037 of 36864)
# Epoch [501/1000], MSE loss: 0.0006, Lasso sbg loss: 0.0000, Lasso st loss: 0.0000, Lasso weight loss: 0.0000, Weight Sparsity: 0.0000 (0 of 37748736), Sbg Sparsity: 0.9989 (36824 of 36864), St Sparsity: 0.0283 (1044 of 36864)
# Epoch [601/1000], MSE loss: 0.0002, Lasso sbg loss: 0.0000, Lasso st loss: 0.0000, Lasso weight loss: 0.0000, Weight Sparsity: 0.0000 (0 of 37748736), Sbg Sparsity: 0.9995 (36847 of 36864), St Sparsity: 0.0285 (1051 of 36864)
# Epoch [701/1000], MSE loss: 0.0001, Lasso sbg loss: 0.0000, Lasso st loss: 0.0000, Lasso weight loss: 0.0000, Weight Sparsity: 0.0000 (0 of 37748736), Sbg Sparsity: 0.9996 (36850 of 36864), St Sparsity: 0.0290 (1068 of 36864)
# Epoch [801/1000], MSE loss: 0.0000, Lasso sbg loss: 0.0000, Lasso st loss: 0.0000, Lasso weight loss: 0.0000, Weight Sparsity: 0.0000 (0 of 37748736), Sbg Sparsity: 0.9998 (36856 of 36864), St Sparsity: 0.0290 (1068 of 36864)
# Epoch [901/1000], MSE loss: 0.0000, Lasso sbg loss: 0.0000, Lasso st loss: 0.0000, Lasso weight loss: 0.0000, Weight Sparsity: 0.0000 (0 of 37748736), Sbg Sparsity: 0.9996 (36848 of 36864), St Sparsity: 0.0292 (1075 of 36864)
# Using device: cuda
#
# Training with zero_out_threshold = 0.1, lasso_sbg_lambda = 0.0, lasso_st_lambda = 0.0, lasso_weight_lambda = 0.0
# Epoch [1/1000], MSE loss: 2.0231, Lasso sbg loss: 0.0000, Lasso st loss: 0.0000, Lasso weight loss: 0.0000, Weight Sparsity: 0.0000 (0 of 37748736), Sbg Sparsity: 0.8425 (31058 of 36864), St Sparsity: 0.8413 (31014 of 36864)
# Epoch [101/1000], MSE loss: 0.0001, Lasso sbg loss: 0.0000, Lasso st loss: 0.0000, Lasso weight loss: 0.0000, Weight Sparsity: 0.0000 (0 of 37748736), Sbg Sparsity: 1.0000 (36864 of 36864), St Sparsity: 0.4658 (17171 of 36864)
# Epoch [201/1000], MSE loss: 0.0002, Lasso sbg loss: 0.0000, Lasso st loss: 0.0000, Lasso weight loss: 0.0000, Weight Sparsity: 0.0000 (0 of 37748736), Sbg Sparsity: 1.0000 (36864 of 36864), St Sparsity: 0.4661 (17183 of 36864)
# Epoch [301/1000], MSE loss: 0.0002, Lasso sbg loss: 0.0000, Lasso st loss: 0.0000, Lasso weight loss: 0.0000, Weight Sparsity: 0.0000 (0 of 37748736), Sbg Sparsity: 1.0000 (36864 of 36864), St Sparsity: 0.4665 (17198 of 36864)
# Epoch [401/1000], MSE loss: 0.0003, Lasso sbg loss: 0.0000, Lasso st loss: 0.0000, Lasso weight loss: 0.0000, Weight Sparsity: 0.0000 (0 of 37748736), Sbg Sparsity: 1.0000 (36864 of 36864), St Sparsity: 0.4668 (17209 of 36864)
# Epoch [501/1000], MSE loss: 0.0002, Lasso sbg loss: 0.0000, Lasso st loss: 0.0000, Lasso weight loss: 0.0000, Weight Sparsity: 0.0000 (0 of 37748736), Sbg Sparsity: 1.0000 (36863 of 36864), St Sparsity: 0.4673 (17227 of 36864)
# Epoch [601/1000], MSE loss: 0.0003, Lasso sbg loss: 0.0000, Lasso st loss: 0.0000, Lasso weight loss: 0.0000, Weight Sparsity: 0.0000 (0 of 37748736), Sbg Sparsity: 1.0000 (36864 of 36864), St Sparsity: 0.4676 (17236 of 36864)
# Epoch [701/1000], MSE loss: 0.0003, Lasso sbg loss: 0.0000, Lasso st loss: 0.0000, Lasso weight loss: 0.0000, Weight Sparsity: 0.0000 (0 of 37748736), Sbg Sparsity: 1.0000 (36864 of 36864), St Sparsity: 0.4682 (17259 of 36864)
# Epoch [801/1000], MSE loss: 0.0001, Lasso sbg loss: 0.0000, Lasso st loss: 0.0000, Lasso weight loss: 0.0000, Weight Sparsity: 0.0000 (0 of 37748736), Sbg Sparsity: 1.0000 (36864 of 36864), St Sparsity: 0.4686 (17273 of 36864)
# Epoch [901/1000], MSE loss: 0.0000, Lasso sbg loss: 0.0000, Lasso st loss: 0.0000, Lasso weight loss: 0.0000, Weight Sparsity: 0.0000 (0 of 37748736), Sbg Sparsity: 1.0000 (36864 of 36864), St Sparsity: 0.4695 (17309 of 36864)

# %%
plot_comparison_curves(sbg_sparsity, title = 'Sbg sparsity', label_title='threshold')
