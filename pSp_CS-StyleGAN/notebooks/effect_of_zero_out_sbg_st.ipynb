# %%
# locate the root folder
CODE_DIR = '/home/ids/yuhe/Projects/CA_with_GAN/3_code_styleGAN/pSp_encoder_constructive/'

import os
os.chdir(f'{CODE_DIR}')

notebook_path = os.getcwd()
print('Current working directory is:', '\n', notebook_path) 

# import time
# import math
# from typing import Tuple, Optional, List

import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import torch.nn.functional as F
import matplotlib.pyplot as plt
from notebooks.def_lasso_functions import validate, train_model_function, get_model_weights_info, show_latent_map, Options, calculate_latent_loss, calculate_weight_sparsity, calculate_output_sparsity, plot_results, plot_comparison_curves
# Out:
# Current working directory is:
#  /home/ids/yuhe/Projects/CA_with_GAN/3_code_styleGAN/pSp_encoder_constructive

# %% [markdown]
# ### Test zero_out threshold effect on silent target

# %%
num_epochs = 2000
learning_rate=0.01

zero_out_bg=True
zero_out_t=True
#zero_out_threshold=0.0
zero_out_type='hard'
lasso_sbg_lambda=1e-8
lasso_st_lambda=1e-8
lasso_weight_lambda=0.00

params_list=[1e-6, 1e-5, 1e-4, 0.001]  # zero_out_threshold

weight_sparsity = {}
sbg_sparsity = {}
st_sparsity = {}
lasso_sbg_losses = {}
lasso_st_losses = {}
lasso_weight_losses = {}
MSE_losses = {}
trained_models = {}


for param in params_list:

    trained_model, trackers, latent_bg_target, latent_t_target = train_model_function(num_epochs=num_epochs, learning_rate=0.01, 
                                                    style_dim=18, latent_dim=512, mlp_norm_type='no_dim',
                                                    zero_out_bg=zero_out_bg, zero_out_t=zero_out_t, zero_out_threshold=param, zero_out_type=zero_out_type, 
                                                    lasso_sbg_lambda=lasso_sbg_lambda, lasso_st_lambda=lasso_st_lambda, lasso_output_type='element', 
                                                    lasso_weight_lambda=lasso_weight_lambda, lasso_weight_type='all', 
                                                    track_weight_threshold=0.0, track_output_threshold=0.0,
                                                    plot_curves=False, device='cuda')
    
    # Store the results and trained model for the current lasso_output_lambda
    weight_sparsity[param] = trackers['weight_sparsity_tracker']
    sbg_sparsity[param] = trackers['sbg_sparsity_tracker']
    st_sparsity[param] = trackers['st_sparsity_tracker']
    lasso_sbg_losses[param] = trackers['lasso_sbg_tracker']
    lasso_st_losses[param] = trackers['lasso_st_tracker']
    lasso_weight_losses[param] = trackers['lasso_weight_tracker']
    MSE_losses[param] = trackers['latent_MSE_tracker']
    trained_models[param] = trained_model

plot_comparison_curves(sbg_sparsity, title = 'Sbg sparsity', label_title='threshold')
plot_comparison_curves(st_sparsity,'St sparsity', label_title='threshold')
plot_comparison_curves(lasso_sbg_losses,'lasso Sbg loss', label_title='threshold')
plot_comparison_curves(lasso_st_losses,'lasso St loss', label_title='threshold')

for param in params_list:
    latent_bg_s, latent_t_s = validate(trained_models[param], latent_bg_target, latent_t_target)
    show_latent_map(latent_t_s, img_idx = 0, show_weight = 50)
# Out:
# Using device: cuda
#
# Training with zero_out_threshold = 1e-06, lasso_sbg_lambda = 1e-08, lasso_st_lambda = 1e-08, lasso_weight_lambda = 0.0
# Epoch [1/2000], MSE loss: 2.0359, Lasso sbg loss: 0.0000, Lasso st loss: 0.0000, Lasso weight loss: 0.0000, Weight Sparsity: 0.0000 (0 of 37748736), Sbg Sparsity: 0.0000 (0 of 36864), St Sparsity: 0.0000 (0 of 36864)
# Epoch [201/2000], MSE loss: 0.0001, Lasso sbg loss: 0.0000, Lasso st loss: 0.0002, Lasso weight loss: 0.0000, Weight Sparsity: 0.0000 (0 of 37748736), Sbg Sparsity: 0.0002 (7 of 36864), St Sparsity: 0.0000 (0 of 36864)
# Epoch [401/2000], MSE loss: 0.0003, Lasso sbg loss: 0.0000, Lasso st loss: 0.0002, Lasso weight loss: 0.0000, Weight Sparsity: 0.0000 (0 of 37748736), Sbg Sparsity: 0.0007 (26 of 36864), St Sparsity: 0.0001 (2 of 36864)
# Epoch [601/2000], MSE loss: 0.0001, Lasso sbg loss: 0.0000, Lasso st loss: 0.0002, Lasso weight loss: 0.0000, Weight Sparsity: 0.0000 (0 of 37748736), Sbg Sparsity: 0.0014 (50 of 36864), St Sparsity: 0.0000 (0 of 36864)
# Epoch [801/2000], MSE loss: 0.0001, Lasso sbg loss: 0.0000, Lasso st loss: 0.0002, Lasso weight loss: 0.0000, Weight Sparsity: 0.0000 (0 of 37748736), Sbg Sparsity: 0.0018 (65 of 36864), St Sparsity: 0.0000 (1 of 36864)
# Epoch [1001/2000], MSE loss: 0.0001, Lasso sbg loss: 0.0000, Lasso st loss: 0.0002, Lasso weight loss: 0.0000, Weight Sparsity: 0.0000 (0 of 37748736), Sbg Sparsity: 0.0032 (118 of 36864), St Sparsity: 0.0000 (0 of 36864)
# Epoch [1201/2000], MSE loss: 0.0004, Lasso sbg loss: 0.0000, Lasso st loss: 0.0002, Lasso weight loss: 0.0000, Weight Sparsity: 0.0000 (0 of 37748736), Sbg Sparsity: 0.0014 (53 of 36864), St Sparsity: 0.0000 (0 of 36864)
# Epoch [1401/2000], MSE loss: 0.0002, Lasso sbg loss: 0.0000, Lasso st loss: 0.0002, Lasso weight loss: 0.0000, Weight Sparsity: 0.0000 (0 of 37748736), Sbg Sparsity: 0.0035 (128 of 36864), St Sparsity: 0.0000 (1 of 36864)
# Epoch [1601/2000], MSE loss: 0.0003, Lasso sbg loss: 0.0000, Lasso st loss: 0.0002, Lasso weight loss: 0.0000, Weight Sparsity: 0.0000 (0 of 37748736), Sbg Sparsity: 0.0045 (165 of 36864), St Sparsity: 0.0000 (1 of 36864)
# Epoch [1801/2000], MSE loss: 0.0000, Lasso sbg loss: 0.0000, Lasso st loss: 0.0002, Lasso weight loss: 0.0000, Weight Sparsity: 0.0000 (0 of 37748736), Sbg Sparsity: 0.0044 (162 of 36864), St Sparsity: 0.0000 (1 of 36864)
# Using device: cuda
#
# Training with zero_out_threshold = 1e-05, lasso_sbg_lambda = 1e-08, lasso_st_lambda = 1e-08, lasso_weight_lambda = 0.0
# Epoch [1/2000], MSE loss: 2.0285, Lasso sbg loss: 0.0000, Lasso st loss: 0.0000, Lasso weight loss: 0.0000, Weight Sparsity: 0.0000 (0 of 37748736), Sbg Sparsity: 0.0002 (7 of 36864), St Sparsity: 0.0003 (10 of 36864)
# Epoch [201/2000], MSE loss: 0.0001, Lasso sbg loss: 0.0000, Lasso st loss: 0.0002, Lasso weight loss: 0.0000, Weight Sparsity: 0.0000 (0 of 37748736), Sbg Sparsity: 0.0020 (75 of 36864), St Sparsity: 0.0006 (21 of 36864)
# Epoch [401/2000], MSE loss: 0.0001, Lasso sbg loss: 0.0000, Lasso st loss: 0.0002, Lasso weight loss: 0.0000, Weight Sparsity: 0.0000 (0 of 37748736), Sbg Sparsity: 0.0077 (283 of 36864), St Sparsity: 0.0000 (0 of 36864)
# Epoch [601/2000], MSE loss: 0.0002, Lasso sbg loss: 0.0000, Lasso st loss: 0.0002, Lasso weight loss: 0.0000, Weight Sparsity: 0.0000 (0 of 37748736), Sbg Sparsity: 0.0155 (570 of 36864), St Sparsity: 0.0000 (0 of 36864)
# Epoch [801/2000], MSE loss: 0.0001, Lasso sbg loss: 0.0000, Lasso st loss: 0.0002, Lasso weight loss: 0.0000, Weight Sparsity: 0.0000 (0 of 37748736), Sbg Sparsity: 0.0180 (664 of 36864), St Sparsity: 0.0000 (1 of 36864)
# Epoch [1001/2000], MSE loss: 0.0012, Lasso sbg loss: 0.0000, Lasso st loss: 0.0002, Lasso weight loss: 0.0000, Weight Sparsity: 0.0000 (0 of 37748736), Sbg Sparsity: 0.0231 (853 of 36864), St Sparsity: 0.0001 (2 of 36864)
# Epoch [1201/2000], MSE loss: 0.0001, Lasso sbg loss: 0.0000, Lasso st loss: 0.0002, Lasso weight loss: 0.0000, Weight Sparsity: 0.0000 (0 of 37748736), Sbg Sparsity: 0.0374 (1379 of 36864), St Sparsity: 0.0001 (5 of 36864)
# Epoch [1401/2000], MSE loss: 0.0001, Lasso sbg loss: 0.0000, Lasso st loss: 0.0002, Lasso weight loss: 0.0000, Weight Sparsity: 0.0000 (0 of 37748736), Sbg Sparsity: 0.0440 (1623 of 36864), St Sparsity: 0.0002 (9 of 36864)
# Epoch [1601/2000], MSE loss: 0.0002, Lasso sbg loss: 0.0000, Lasso st loss: 0.0002, Lasso weight loss: 0.0000, Weight Sparsity: 0.0000 (0 of 37748736), Sbg Sparsity: 0.0387 (1425 of 36864), St Sparsity: 0.0004 (15 of 36864)
# Epoch [1801/2000], MSE loss: 0.0001, Lasso sbg loss: 0.0000, Lasso st loss: 0.0002, Lasso weight loss: 0.0000, Weight Sparsity: 0.0000 (0 of 37748736), Sbg Sparsity: 0.0266 (982 of 36864), St Sparsity: 0.0001 (2 of 36864)
# Using device: cuda
#
# Training with zero_out_threshold = 0.0001, lasso_sbg_lambda = 1e-08, lasso_st_lambda = 1e-08, lasso_weight_lambda = 0.0
# Epoch [1/2000], MSE loss: 2.0285, Lasso sbg loss: 0.0000, Lasso st loss: 0.0000, Lasso weight loss: 0.0000, Weight Sparsity: 0.0000 (0 of 37748736), Sbg Sparsity: 0.0023 (85 of 36864), St Sparsity: 0.0030 (112 of 36864)
# Epoch [201/2000], MSE loss: 0.0001, Lasso sbg loss: 0.0000, Lasso st loss: 0.0002, Lasso weight loss: 0.0000, Weight Sparsity: 0.0000 (0 of 37748736), Sbg Sparsity: 0.0166 (612 of 36864), St Sparsity: 0.0016 (60 of 36864)
# Epoch [401/2000], MSE loss: 0.0001, Lasso sbg loss: 0.0000, Lasso st loss: 0.0002, Lasso weight loss: 0.0000, Weight Sparsity: 0.0000 (0 of 37748736), Sbg Sparsity: 0.0466 (1718 of 36864), St Sparsity: 0.0006 (23 of 36864)
# Epoch [601/2000], MSE loss: 0.0003, Lasso sbg loss: 0.0000, Lasso st loss: 0.0002, Lasso weight loss: 0.0000, Weight Sparsity: 0.0000 (0 of 37748736), Sbg Sparsity: 0.0830 (3061 of 36864), St Sparsity: 0.0006 (21 of 36864)
# Epoch [801/2000], MSE loss: 0.0004, Lasso sbg loss: 0.0000, Lasso st loss: 0.0002, Lasso weight loss: 0.0000, Weight Sparsity: 0.0000 (0 of 37748736), Sbg Sparsity: 0.1073 (3956 of 36864), St Sparsity: 0.0007 (24 of 36864)
# Epoch [1001/2000], MSE loss: 0.0002, Lasso sbg loss: 0.0000, Lasso st loss: 0.0002, Lasso weight loss: 0.0000, Weight Sparsity: 0.0000 (0 of 37748736), Sbg Sparsity: 0.1620 (5973 of 36864), St Sparsity: 0.0008 (29 of 36864)
# Epoch [1201/2000], MSE loss: 0.0002, Lasso sbg loss: 0.0000, Lasso st loss: 0.0002, Lasso weight loss: 0.0000, Weight Sparsity: 0.0000 (0 of 37748736), Sbg Sparsity: 0.1943 (7161 of 36864), St Sparsity: 0.0015 (55 of 36864)
# Epoch [1401/2000], MSE loss: 0.0003, Lasso sbg loss: 0.0000, Lasso st loss: 0.0002, Lasso weight loss: 0.0000, Weight Sparsity: 0.0000 (0 of 37748736), Sbg Sparsity: 0.2361 (8704 of 36864), St Sparsity: 0.0012 (46 of 36864)
# Epoch [1601/2000], MSE loss: 0.0001, Lasso sbg loss: 0.0000, Lasso st loss: 0.0002, Lasso weight loss: 0.0000, Weight Sparsity: 0.0000 (0 of 37748736), Sbg Sparsity: 0.2283 (8417 of 36864), St Sparsity: 0.0014 (51 of 36864)
# Epoch [1801/2000], MSE loss: 0.0001, Lasso sbg loss: 0.0000, Lasso st loss: 0.0002, Lasso weight loss: 0.0000, Weight Sparsity: 0.0000 (0 of 37748736), Sbg Sparsity: 0.2569 (9471 of 36864), St Sparsity: 0.0028 (105 of 36864)
# Using device: cuda
#
# Training with zero_out_threshold = 0.001, lasso_sbg_lambda = 1e-08, lasso_st_lambda = 1e-08, lasso_weight_lambda = 0.0
# Epoch [1/2000], MSE loss: 2.0166, Lasso sbg loss: 0.0000, Lasso st loss: 0.0000, Lasso weight loss: 0.0000, Weight Sparsity: 0.0000 (0 of 37748736), Sbg Sparsity: 0.0258 (950 of 36864), St Sparsity: 0.0252 (928 of 36864)
# Epoch [201/2000], MSE loss: 0.0001, Lasso sbg loss: 0.0000, Lasso st loss: 0.0002, Lasso weight loss: 0.0000, Weight Sparsity: 0.0000 (0 of 37748736), Sbg Sparsity: 0.1255 (4627 of 36864), St Sparsity: 0.0056 (207 of 36864)
# Epoch [401/2000], MSE loss: 0.0002, Lasso sbg loss: 0.0000, Lasso st loss: 0.0002, Lasso weight loss: 0.0000, Weight Sparsity: 0.0000 (0 of 37748736), Sbg Sparsity: 0.3287 (12117 of 36864), St Sparsity: 0.0085 (313 of 36864)
# Epoch [601/2000], MSE loss: 0.0004, Lasso sbg loss: 0.0000, Lasso st loss: 0.0002, Lasso weight loss: 0.0000, Weight Sparsity: 0.0000 (0 of 37748736), Sbg Sparsity: 0.5081 (18732 of 36864), St Sparsity: 0.0075 (275 of 36864)
# Epoch [801/2000], MSE loss: 0.0003, Lasso sbg loss: 0.0000, Lasso st loss: 0.0002, Lasso weight loss: 0.0000, Weight Sparsity: 0.0000 (0 of 37748736), Sbg Sparsity: 0.6665 (24570 of 36864), St Sparsity: 0.0113 (416 of 36864)
# Epoch [1001/2000], MSE loss: 0.0002, Lasso sbg loss: 0.0000, Lasso st loss: 0.0002, Lasso weight loss: 0.0000, Weight Sparsity: 0.0000 (0 of 37748736), Sbg Sparsity: 0.7488 (27602 of 36864), St Sparsity: 0.0077 (285 of 36864)
# Epoch [1201/2000], MSE loss: 0.0001, Lasso sbg loss: 0.0000, Lasso st loss: 0.0002, Lasso weight loss: 0.0000, Weight Sparsity: 0.0000 (0 of 37748736), Sbg Sparsity: 0.8307 (30624 of 36864), St Sparsity: 0.0210 (775 of 36864)
# Epoch [1401/2000], MSE loss: 0.0006, Lasso sbg loss: 0.0000, Lasso st loss: 0.0002, Lasso weight loss: 0.0000, Weight Sparsity: 0.0000 (0 of 37748736), Sbg Sparsity: 0.8218 (30294 of 36864), St Sparsity: 0.0139 (514 of 36864)
# Epoch [1601/2000], MSE loss: 0.0003, Lasso sbg loss: 0.0000, Lasso st loss: 0.0002, Lasso weight loss: 0.0000, Weight Sparsity: 0.0000 (0 of 37748736), Sbg Sparsity: 0.8955 (33010 of 36864), St Sparsity: 0.0113 (417 of 36864)
# Epoch [1801/2000], MSE loss: 0.0001, Lasso sbg loss: 0.0000, Lasso st loss: 0.0002, Lasso weight loss: 0.0000, Weight Sparsity: 0.0000 (0 of 37748736), Sbg Sparsity: 0.9280 (34208 of 36864), St Sparsity: 0.0184 (678 of 36864)
# Testing results:
# Weight Sparsity: 0.0000 (0 of 37748736), Sbg Sparsity: 0.0000 (0 of 36864), St Sparsity: 0.0000 (0 of 36864)
# Testing results:
# Weight Sparsity: 0.0000 (0 of 37748736), Sbg Sparsity: 0.0003 (10 of 36864), St Sparsity: 0.0003 (12 of 36864)
# Testing results:
# Weight Sparsity: 0.0000 (0 of 37748736), Sbg Sparsity: 0.0022 (80 of 36864), St Sparsity: 0.0024 (87 of 36864)
# Testing results:
# Weight Sparsity: 0.0000 (0 of 37748736), Sbg Sparsity: 0.9440 (34801 of 36864), St Sparsity: 0.0215 (793 of 36864)

# %%
1e-5
# Out:
# 1e-05

# %%
# plot_comparison_curves(sbg_sparsity, title = 'Sbg sparsity', label_title='threshold')
# plot_comparison_curves(st_sparsity,'St sparsity', label_title='threshold')
# plot_comparison_curves(lasso_sbg_losses,'lasso Sbg loss', label_title='threshold')
# plot_comparison_curves(lasso_st_losses,'lasso St loss', label_title='threshold')

for param in params_list:
    latent_bg_s, latent_t_s = validate(trained_models[param], latent_bg_target, latent_t_target)
    show_latent_map(latent_bg_s, img_idx = 0, show_weight = 50)
    show_latent_map(latent_t_s, img_idx = 0, show_weight = 50)
# Out:
# Testing results:
# Weight Sparsity: 0.0000 (0 of 37748736), Sbg Sparsity: 0.0000 (0 of 36864), St Sparsity: 0.0000 (0 of 36864)
# Testing results:
# Weight Sparsity: 0.0000 (0 of 37748736), Sbg Sparsity: 0.0003 (10 of 36864), St Sparsity: 0.0003 (12 of 36864)
# Testing results:
# Weight Sparsity: 0.0000 (0 of 37748736), Sbg Sparsity: 0.0022 (80 of 36864), St Sparsity: 0.0024 (87 of 36864)
# Testing results:
# Weight Sparsity: 0.0000 (0 of 37748736), Sbg Sparsity: 0.9440 (34801 of 36864), St Sparsity: 0.0215 (793 of 36864)
